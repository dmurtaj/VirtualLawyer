# %% [markdown]
# ## Chatbot Analysis

# %%
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ### Chatverlauf Leon

# %%
# JSON-Daten aus einer Datei lesen
with open('analyse-leon.json') as f:
    results = json.load(f)

# Liste der Themen und Sentiment-Werte erstellen
topics = [result["topic"] for result in results]
sentiments = [result["sentiment"] for result in results]

# Listen umkehren
topics = topics[::-1]
sentiments = sentiments[::-1]

# Plot erstellen
plt.barh(topics, sentiments, color=['green' if s >= 0 else 'red' for s in sentiments])
plt.xlabel('Sentiment-Wert')
plt.ylabel('Thema')
plt.title('Sentimentanalyse')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Chatverlauf Valent

# %%
# JSON-Daten aus einer Datei lesen
with open('analyse-valent.json') as f:
    results = json.load(f)

# Liste der Themen und Sentiment-Werte erstellen
topics = [result["topic"] for result in results]
sentiments = [result["sentiment"] for result in results]

# Listen umkehren
topics = topics[::-1]
sentiments = sentiments[::-1]

# Plot erstellen
plt.barh(topics, sentiments, color=['green' if s >= 0 else 'red' for s in sentiments])
plt.xlabel('Sentiment-Wert')
plt.ylabel('Thema')
plt.title('Sentimentanalyse')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Chatverlauf Dorentina

# %%
# JSON-Daten aus einer Datei lesen
with open('analyse-dorentina.json') as f:
    results = json.load(f)

# Liste der Themen und Sentiment-Werte erstellen
topics = [result["topic"] for result in results]
sentiments = [result["sentiment"] for result in results]

# Listen umkehren
topics = topics[::-1]
sentiments = sentiments[::-1]

# Plot erstellen
plt.barh(topics, sentiments, color=['green' if s >= 0 else 'red' for s in sentiments])
plt.xlabel('Sentiment-Wert')
plt.ylabel('Thema')
plt.title('Sentimentanalyse')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Chatverlauf Olisa

# %%
# JSON-Daten aus einer Datei lesen
with open('analyse-olisa.json') as f:
    results = json.load(f)

# Liste der Themen und Sentiment-Werte erstellen
topics = [result["topic"] for result in results]
sentiments = [result["sentiment"] for result in results]

# Listen umkehren
topics = topics[::-1]
sentiments = sentiments[::-1]

# Plot erstellen
plt.barh(topics, sentiments, color=['green' if s >= 0 else 'red' for s in sentiments])
plt.xlabel('Sentiment-Wert')
plt.ylabel('Thema')
plt.title('Sentimentanalyse')
plt.grid(True)
plt.show()
